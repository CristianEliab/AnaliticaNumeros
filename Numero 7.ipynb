# %% [markdown]
# <img  src=http://repository.icesi.edu.co/biblioteca_digital/image/icesi-logo.svg height="250" width="250">
#
# **Autor: Felipe Cortes, Cristian Rodriguez**

# %% [markdown]
# Se observaron cuantas veces se encuentra el número 7 en el dataset de imágenes de sklearn.datasets.

# %%
from sklearn.datasets import load_digits
import pylab as plt

# %%
digits = load_digits()
numImagenes = len(digits.images) # Numero de imagenes, len es un método que provee el tamaño del arreglo
y = digits.target # el método nos provee las etiquetas de las imágenes en un arreglo
numero = 7; # El número a buscar

# Método que devuelve el total de números en el dataset
def numeroTotal(num,totalImagenes):
    numY = 0;
    for i in range(totalImagenes):
        if(y[i] == num):
            numY += 1;
    return numY;

# Método que devuelve todas las imágenes del número pasado por parametro en el dataset
def visualizarTodosNumeros(num,totalImagenes):
    for i in range(totalImagenes):
        if(y[i] == num):
            plt.imshow(digits.images[i], cmap=plt.cm.gray_r)
            plt.title('Pred:' + str(i))
            plt.show()

def visualizacion_2():
    images_and_predictions = list(zip(digits.images, y))
    for index, (image, prediction) in enumerate(images_and_predictions[:4]):
        plt.matshow(digits.images[index]) # Imprimir una imagen dada
        print(digits.images[index])
        plt.title('Pred: %i' % prediction)
        plt.show()

# %%
# Mostrar la información: 

print('Número total de imágenes: ' + str(numImagenes));
print('Número total de 7 en el dataset: ' + str(numeroTotal(numero,numImagenes)));
# Out:
# Número total de imágenes: 1797
# Número total de 7 en el dataset: 179

# %%
# Método que devuelve todas las imágenes del número pasado por parametro en el dataset

visualizarTodosNumeros(numero,numImagenes)

# %%
def promedio(imagen):
    num_pixel = 0;
    total = 0;
    for i in range(8):
        for j in range(8):
            if(imagen[i][j]!=0):
                num_pixel += imagen[i][j];
                total += 1;
    promedio = num_pixel//total;
    return promedio;

def dar_promedio(num,totalImagenes):
    promedio = 0;
    for i in range(totalImagenes):
        if(y[i] == num):
            promedio = promedio(digits.images[i]);
    return promedio;
            
def ver_linea_superior(imagen):
    acerto = True;
    
    return acerto;

def ver_linea_intermedia(imagen):
    acerto = True;
    return acerto;

def ver_linea_inferior(imagen):
    acerto = False;
    n_p_s = 0;
    n_p_i = 0;
    for i in range(6,7):
        for j in range(2,6):
            if(imagen[i][j] > 12):
                n_p_s += 1;
    for i in range(7,8):
        for j in range(2,6):
            if(imagen[i][j] > 12):
                n_p_i += 1;
    if(n_p_s == 2 and n_p_i == 2):
        acerto = True;
    return acerto;

def ver_diagonal(imagen):
    acerto = True;
    return acerto;

# %%
def detectar_numero(imagen):
    acerto = True;
    met_1 = ver_linea_superior(imagen);
    met_2 = ver_linea_intermedia(imagen);
    met_3 = ver_linea_inferior(imagen);
    met_4 = ver_diagonal(imagen);
    if (met_1 == True and met_2 == True and met_3 == True and met_4 == True):
        return acerto;
    else:
        acerto = False;
    return acerto;

def prueba(imagen):
    met_3 = ver_linea_inferior(imagen);
    if (met_3 == True):
        return True;

def modeloMecanico(numero, totalImagenes):
    numAciertos = 0;
    for i in range(totalImagenes):
        if((detectar_numero(digits.images[i]) == True) and (y[i] == numero)):
            numAciertos += 1;
    return numAciertos;

def modeloMecanico_test(numero, totalImagenes):
    numAciertos = 0;
    for i in range(totalImagenes):
        if((prueba(digits.images[i]) == True) and (y[i] == numero)):
            numAciertos += 1;
    return numAciertos;

# %%
print(dar_promedio(numero,numImagenes));
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-896c27fdc147> in <module>
# ----> 1 print(dar_promedio(numero,numImagenes));
#
# <ipython-input-30-6e9f0f9219b1> in dar_promedio(num, totalImagenes)
#      15     for i in range(totalImagenes):
#      16         if(y[i] == num):
# ---> 17             promedio = promedio(digits.images[i]);
#      18     return promedio;
#      19
#
# TypeError: 'int' object is not callable

# %%
numero = 4;
total = numeroTotal(numero,numImagenes);
print("Número total de " + str(total));
print("Numero de dos encontrados correctamente: ", str(modeloMecanico_test(numero,numImagenes)))
# Out:
# Número total de 181
# Numero de dos encontrados correctamente:  1

# %%
aciertos = 0
totales = 0
def limpiar(matrizImagen):
    
    for i in range(8):
        for j in range(8):
            if (matrizImagen[i,j]<9):
                matrizImagen[i,j] = 0
    return matrizImagen


def contarPuntosCurva(matrizImagen,i,j):
    cantidad = 0
    if(i>=1 and j>=1 and i<6 and j<6):
        if (matrizImagen[i,j+1]>8):
            cantidad = cantidad+1 
        if (matrizImagen[i+1,j-1]>8):
            cantidad = cantidad+1 
        if (matrizImagen[i+1,j]>8):
            cantidad = cantidad+1 
        if (matrizImagen[i+1,j+1]>8):
            cantidad = cantidad+1 
    return cantidad

def encontrarCurva(matrizImagen):
    respuestaCurva = False
    valor = 0
    for i in range(8):
        for j in range(8):
            if (matrizImagen[i,j]>8):
                valor = contarPuntosCurva(matrizImagen,i,j)
                if valor>2:
                    respuestaCurva = True
    return respuestaCurva;


def inicial(matriz):
    for i in range(7,4):
        for j in range(1,4):
            if (matrizImagen[i,j]>8):
                return i,j
    return 7,1

def isRecta(matriz,i,j):
    cantidadCiclos = 0
    termino = False
    if(cantidadCiclos>3):
        termino = True

    if (i<7):
        if (matriz[i-1,j+1]>8 and termino==False):
            cantidadCiclos = cantidadCiclos+1
            isRecta(matriz,i-1,j+1)
        if (matriz[i,j+1]>8 and termino==False):
            cantidadCiclos = cantidadCiclos+1
            isRecta(matriz,i,j+1)

        if (matriz[i+1,j+1]>8 and termino==False):
            cantidadCiclos = cantidadCiclos+1
            isRecta(matriz,i+1,j+1)
    return termino

def encontrarDiagonal(matrizImagen):
    encontro = False
    inicialX,inicialY = inicial(matrizImagen)
    respu=isDiagonal(matrizImagen,inicialX,inicialY)
    if(respu==True):
        encontro = True
    return encontro

def isDiagonal(matriz,i,j):
    cantidadCiclos = 0
    termino = False
    if(cantidadCiclos>3):
        termino = True
    if(i>=1 and j>=1 and i<6 and j<6):
        if (matriz[i-1,j]>8 and termino==False):
            cantidadCiclos = cantidadCiclos+1
            isDiagonal(matriz,i-1,j)
        if (matriz[i-1,j+1]>8 and termino == False):
            cantidadCiclos = cantidadCiclos+1
            isDiagonal(matriz,i-1,j+1)
        if (matriz[i,j+1]>8 and termino == False):
            cantidadCiclos = cantidadCiclos+1
            isDiagonal(matriz,i,j+1)
    return termino

def EncontrarRecta(matrizImagen) :
    encontro=False
    if(matrizImagen[7][2]>8 or matrizImagen[6][2]>8 ):
        if (matrizImagen[7][3]>8 or matrizImagen[6][3]>8 ) :
            if (matrizImagen[7][4]>8 or matrizImagen[6][4]>8 ):
                encontro=True
    return encontro
